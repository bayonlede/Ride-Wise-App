# %% [markdown]
# # RideWise: Customer Analytics & Churn Prediction
#
# This project focused on building a **customer analytics and churn prediction engine** for RideWise, a leading European mobility technology company. With over 200,000 customers and 800,000 monthly trips across major cities, RideWise faces a **25% quarterly churn challenge** that impacts revenue and growth.
#
# The project integrates **customer segmentation, churn modeling, and real-time analytics** to deliver proactive retention strategies. Using Python, scikit-learn, FastAPI, and Streamlit, the solution provides:
#
# - **Churn Prediction**: Identifying at-risk users before they leave.
# - **Customer Segmentation**: Tailoring retention strategies for commuters, occasional users, and weekend riders.
# - **Real-time Insights**: API-driven risk scoring and dashboards for instant decision-making.
#
# This notebook serves as the foundation for exploring the datasets, implementing machine learning models, and demonstrating how data-driven insights can reduce churn, increase customer lifetime value, and optimize marketing spend.

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing required libraries for RideWise Customer Analytics & Churn Prediction

# %%
# Data manipulation & analysis
import pandas as pd
import numpy as np
from datetime import datetime as dt

# Machine learning models & evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Ingestion: Loading RideWise datasets

# %%
# Customers dataset: demographics and signup details
riders_df = pd.read_csv('/content/drive/MyDrive/RideWise_Project/ridewise_raw_data/riders.csv')

# Trips dataset: journey paths and payment information
trips_df = pd.read_csv('/content/drive/MyDrive/RideWise_Project/ridewise_raw_data/trips.csv')

# Behavior dataset: monthly aggregated metrics (RFM analysis)
drivers_df = pd.read_csv('/content/drive/MyDrive/RideWise_Project/ridewise_raw_data/drivers.csv')

# Promotions dataset: campaign usage and effectiveness
promotions_df = pd.read_csv('/content/drive/MyDrive/RideWise_Project/ridewise_raw_data/promotions.csv')

# External data: weather, holidays, competitor activity
sessions_df = pd.read_csv('/content/drive/MyDrive/RideWise_Project/ridewise_raw_data/sessions.csv')

# Quick overview of loaded datasets
print("Riders:", riders_df.shape)
print("Trips:", trips_df.shape)
print("Drivers:", drivers_df.shape)
print("Promotions:", promotions_df.shape)
print("Sessions:", sessions_df.shape)
# Out:
# Riders: (10000, 8)
# Trips: (200000, 16)
# Drivers: (5000, 7)
# Promotions: (20, 11)
# Sessions: (50000, 8)

# %% [markdown]
# **trips dataframe**

# %%
trips_df.head(2)
# Out:
#    trip_id user_id driver_id   fare  surge_multiplier   tip payment_type  \
# 0  T000000  R05207    D00315  12.11               1.0  0.00         Card
# 1  T000001  R09453    D03717   8.73               1.0  0.02         Card
#
#                  pickup_time               dropoff_time  pickup_lat  \
# 0  2024-11-27 18:41:50+02:27  2024-11-27 19:33:50+02:27   -1.108123
# 1  2024-10-28 23:13:48+00:14  2024-10-28 23:26:48+00:14    6.675266
#
#    pickup_lng  dropoff_lat  dropoff_lng weather     city loyalty_status
# 0   36.912209    -1.068155    36.875377   Foggy  Nairobi         Bronze
# 1    3.515740     6.641734     3.525620   Sunny    Lagos           Gold

# %%
trips_df[trips_df['user_id'] == 'R00000'].head(3)
# Out:
#        trip_id user_id driver_id   fare  surge_multiplier   tip payment_type  \
# 1144   T001144  R00000    D03414  23.62               1.4  0.00         Card
# 22441  T022441  R00000    D04441  16.31               1.0  0.00         Card
# 24771  T024771  R00000    D00635   9.66               1.0  0.03         Card
#
#                      pickup_time               dropoff_time  pickup_lat  \
# 1144   2024-09-04 00:56:02+02:27  2024-09-04 01:22:02+02:27   -1.115239
# 22441  2025-04-02 17:13:29+02:27  2025-04-02 17:19:29+02:27   -1.350546
# 24771  2024-05-23 09:37:47+02:27  2024-05-23 10:33:47+02:27   -1.316560
#
#        pickup_lng  dropoff_lat  dropoff_lng weather     city loyalty_status
# 1144    36.805339    -1.136842    36.793631   Rainy  Nairobi         Bronze
# 22441   36.745210    -1.339873    36.770102   Sunny  Nairobi         Bronze
# 24771   36.687127    -1.310676    36.680729   Sunny  Nairobi         Bronze

# %% [markdown]
# **riders dataframe**

# %%
riders_df.head(2)
# Out:
#   user_id signup_date loyalty_status        age     city  avg_rating_given  \
# 0  R00000  2025-01-24         Bronze  34.729629  Nairobi               5.0
# 1  R00001  2024-09-09         Bronze  34.571020  Nairobi               4.7
#
#    churn_prob referred_by
# 0    0.142431      R00001
# 1    0.674161         NaN

# %% [markdown]
# **drivers dataframe**

# %%
drivers_df.head(2)
# Out:
#   driver_id  rating vehicle_type signup_date                 last_active  \
# 0    D00000     3.1          SUV  2025-01-20  2025-01-06 18:23:09.312275
# 1    D00001     5.0        Sedan  2023-03-27  2025-04-27 01:44:02.472554
#
#       city  acceptance_rate
# 0    Cairo         0.679555
# 1  Nairobi         0.548786

# %% [markdown]
# **sessions dataframe**

# %%
sessions_df.head(2)
# Out:
#   session_id rider_id               session_time  time_on_app  pages_visited  \
# 0    S000000   R08605  2025-04-27 18:57:06+02:05           79              4
# 1    S000001   R08823  2025-04-27 07:32:22+02:27          101              3
#
#    converted     city loyalty_status
# 0          1    Cairo         Bronze
# 1          0  Nairobi         Silver

# %% [markdown]
# **promotions dataframe**

# %%
promotions_df.head(2)
# Out:
#   promo_id      promo_name    promo_type  promo_value  start_date    end_date  \
# 0     P000  Peak Hour Pass  surge_waiver          1.0  2025-04-26  2025-05-25
# 1     P001  Peak Hour Pass  surge_waiver          1.0  2025-04-26  2025-05-22
#
#   target_segment city_scope                         ab_test_groups  \
# 0            All    Nairobi                                ['All']
# 1            All      Cairo  ['Control', 'Variant A', 'Variant B']
#
#    test_allocation   success_metric
# 0            [1.0]  Usage Frequency
# 1  [0.3, 0.4, 0.3]  Conversion Rate

# %% [markdown]
# **renaming the `rider_id` column in sessions_df into `user_id`**

# %%
sessions_df.rename(columns={'rider_id': 'user_id'}, inplace=True)
promotions_df.rename(columns={'city_scope': 'city'}, inplace=True)

# %%
sessions_df.head(2)
# Out:
#   session_id user_id               session_time  time_on_app  pages_visited  \
# 0    S000000  R08605  2025-04-27 18:57:06+02:05           79              4
# 1    S000001  R08823  2025-04-27 07:32:22+02:27          101              3
#
#    converted     city loyalty_status
# 0          1    Cairo         Bronze
# 1          0  Nairobi         Silver

# %%
sessions_df.shape
# Out:
# (50000, 8)

# %%
promotions_df.head(2)
# Out:
#   promo_id      promo_name    promo_type  promo_value  start_date    end_date  \
# 0     P000  Peak Hour Pass  surge_waiver          1.0  2025-04-26  2025-05-25
# 1     P001  Peak Hour Pass  surge_waiver          1.0  2025-04-26  2025-05-22
#
#   target_segment     city                         ab_test_groups  \
# 0            All  Nairobi                                ['All']
# 1            All    Cairo  ['Control', 'Variant A', 'Variant B']
#
#    test_allocation   success_metric
# 0            [1.0]  Usage Frequency
# 1  [0.3, 0.4, 0.3]  Conversion Rate

# %%
# Merge on the common column 'rider_id'
trips_riders = trips_df.merge(
    riders_df,               # the second DataFrame
    on="user_id",               # column they share
    how="outer"                 # keep all records in both trips and customers df
)

# Quick check of the merged dataset
print(trips_riders.shape)   # shows rows and columns
# Out:
# (200000, 23)

# %%
# merging trips_customers with drivers df
trip_riders_drivers_df = trips_riders.merge(
    drivers_df,
    on="driver_id",
    how="outer"
)

print(trip_riders_drivers_df.shape)
# Out:
# (200000, 29)

# %%
allColumns = trip_riders_drivers_df.columns
for col in allColumns:
    print(col)
# Out:
# trip_id
# user_id
# driver_id
# fare
# surge_multiplier
# tip
# payment_type
# pickup_time
# dropoff_time
# pickup_lat
# pickup_lng
# dropoff_lat
# dropoff_lng
# weather
# city_x
# loyalty_status_x
# signup_date_x
# loyalty_status_y
# age
# city_y
# avg_rating_given
# churn_prob
# referred_by
# rating
# vehicle_type
# signup_date_y
# last_active
# city
# acceptance_rate

# %%
# checking if there are differences between these columns: city, city_x, and city_y

trip_riders_drivers_df[trip_riders_drivers_df['city_x'] != trip_riders_drivers_df['city_y']]
# Out:
# Empty DataFrame
# Columns: [trip_id, user_id, driver_id, fare, surge_multiplier, tip, payment_type, pickup_time, dropoff_time, pickup_lat, pickup_lng, dropoff_lat, dropoff_lng, weather, city_x, loyalty_status_x, signup_date_x, loyalty_status_y, age, city_y, avg_rating_given, churn_prob, referred_by, rating, vehicle_type, signup_date_y, last_active, city, acceptance_rate]
# Index: []
#
# [0 rows x 29 columns]

# %%
trip_riders_drivers_df[trip_riders_drivers_df['city'] != trip_riders_drivers_df['city_y']]
# Out:
# Empty DataFrame
# Columns: [trip_id, user_id, driver_id, fare, surge_multiplier, tip, payment_type, pickup_time, dropoff_time, pickup_lat, pickup_lng, dropoff_lat, dropoff_lng, weather, city_x, loyalty_status_x, signup_date_x, loyalty_status_y, age, city_y, avg_rating_given, churn_prob, referred_by, rating, vehicle_type, signup_date_y, last_active, city, acceptance_rate]
# Index: []
#
# [0 rows x 29 columns]

# %%
trip_riders_drivers_df[trip_riders_drivers_df['city'] != trip_riders_drivers_df['city_x']]
# Out:
# Empty DataFrame
# Columns: [trip_id, user_id, driver_id, fare, surge_multiplier, tip, payment_type, pickup_time, dropoff_time, pickup_lat, pickup_lng, dropoff_lat, dropoff_lng, weather, city_x, loyalty_status_x, signup_date_x, loyalty_status_y, age, city_y, avg_rating_given, churn_prob, referred_by, rating, vehicle_type, signup_date_y, last_active, city, acceptance_rate]
# Index: []
#
# [0 rows x 29 columns]

# %%
# checking if there are differences between loyalty_status_x and loyalty_status_y columns
trip_riders_drivers_df[trip_riders_drivers_df['loyalty_status_x'] != trip_riders_drivers_df['loyalty_status_y']]
# Out:
# Empty DataFrame
# Columns: [trip_id, user_id, driver_id, fare, surge_multiplier, tip, payment_type, pickup_time, dropoff_time, pickup_lat, pickup_lng, dropoff_lat, dropoff_lng, weather, city_x, loyalty_status_x, signup_date_x, loyalty_status_y, age, city_y, avg_rating_given, churn_prob, referred_by, rating, vehicle_type, signup_date_y, last_active, city, acceptance_rate]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# The above indicates there are no differences between these columns hence, the need to drop the duplicated ones from the `segmentation_df`
#
# ---

# %%
# dropping the duplicated columns
trip_riders_drivers_df.drop(columns=['city_x', 'city_y', 'loyalty_status_y'], inplace=True)
trip_riders_drivers_df.rename(columns={'loyalty_status_x': 'loyalty_status'}, inplace=True)
trip_riders_drivers_df.shape
# Out:
# (200000, 26)

# %%
# replacing name appropriately
trip_riders_drivers_df.rename(columns={'signup_date_x': 'user_signup_date'}, inplace=True)
trip_riders_drivers_df.rename(columns={'signup_date_y': 'driver_signup_date'}, inplace=True)
trip_riders_drivers_df.rename(columns={'rating': 'rating_by_rider'}, inplace=True)
trip_riders_drivers_df.rename(columns={'avg_rating_given': 'rating_by_driver'}, inplace=True)

# %%
allColumns = trip_riders_drivers_df.columns
for col in allColumns:
    print(col)
# Out:
# trip_id
# user_id
# driver_id
# fare
# surge_multiplier
# tip
# payment_type
# pickup_time
# dropoff_time
# pickup_lat
# pickup_lng
# dropoff_lat
# dropoff_lng
# weather
# loyalty_status
# user_signup_date
# age
# rating_by_driver
# churn_prob
# referred_by
# rating_by_rider
# vehicle_type
# driver_signup_date
# last_active
# city
# acceptance_rate

# %%
trip_riders_drivers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_id             200000 non-null  object
#  1   user_id             200000 non-null  object
#  2   driver_id           200000 non-null  object
#  3   fare                200000 non-null  float64
#  4   surge_multiplier    200000 non-null  float64
#  5   tip                 200000 non-null  float64
#  6   payment_type        200000 non-null  object
#  7   pickup_time         200000 non-null  object
#  8   dropoff_time        200000 non-null  object
#  9   pickup_lat          200000 non-null  float64
#  10  pickup_lng          200000 non-null  float64
#  11  dropoff_lat         200000 non-null  float64
#  12  dropoff_lng         200000 non-null  float64
#  13  weather             200000 non-null  object
#  14  loyalty_status      200000 non-null  object
#  15  user_signup_date    200000 non-null  object
#  16  age                 200000 non-null  float64
#  17  rating_by_driver    200000 non-null  float64
#  18  churn_prob          200000 non-null  float64
#  19  referred_by         61013 non-null   object
#  20  rating_by_rider     200000 non-null  float64
#  21  vehicle_type        200000 non-null  object
#  22  driver_signup_date  200000 non-null  object
#  23  last_active         200000 non-null  object
#  24  city                200000 non-null  object
#  25  acceptance_rate     200000 non-null  float64
# dtypes: float64(12), object(14)
# memory usage: 39.7+ MB

# %% [markdown]
# The displayed output shows missing values in `referred_by` column

# %%
# displaying the percentage of missing values
trip_riders_drivers_df['referred_by'].isnull().mean()*100
# Out:
# np.float64(69.4935)

# %% [markdown]
# ### Analysis of `referred_by` Column
#
# ![image.png](data:image/png;base64,...)
#
#
#
# The pie chart shows that approximately **70% of the values in the `referred_by` column are missing**, indicating that the majority of customers were **not referred by anyone**. Only **30%** of customers have a recorded referrer.
#
# Given the high proportion of missing values and the fact that these missing entries **cannot be logically inferred or imputed**, the `referred_by` column provides **limited analytical value**. Therefore, it is **reasonable to drop this column** during data preprocessing to improve **data quality** and **model robustness**.
#
#
# ---

# %%
# dropping the referred_by column
trip_riders_drivers_df.drop(columns=['referred_by'], inplace=True)

# %%
# Convert pickup and dropoff times safely, keeping timezone info
trip_riders_drivers_df['pickup_time'] = pd.to_datetime(trip_riders_drivers_df['pickup_time'], utc=True, errors='coerce')
trip_riders_drivers_df['dropoff_time'] = pd.to_datetime(trip_riders_drivers_df['dropoff_time'], utc=True, errors='coerce')
trip_riders_drivers_df['user_signup_date'] = pd.to_datetime(trip_riders_drivers_df['user_signup_date'], utc=True, errors='coerce')
trip_riders_drivers_df['driver_signup_date'] = pd.to_datetime(trip_riders_drivers_df['driver_signup_date'], utc=True, errors='coerce')
trip_riders_drivers_df['last_active'] = pd.to_datetime(trip_riders_drivers_df['last_active'], utc=True, errors='coerce')
trip_riders_drivers_df['age'] = trip_riders_drivers_df['age'].astype(int)


# Check the datatypes
print(trip_riders_drivers_df['pickup_time'].dtype)
print(trip_riders_drivers_df['dropoff_time'].dtype)
print(trip_riders_drivers_df['user_signup_date'].dtype)
print(trip_riders_drivers_df['driver_signup_date'].dtype)
print(trip_riders_drivers_df['age'].dtype)
print(trip_riders_drivers_df['churn_prob'].dtype)
# Out:
# datetime64[ns, UTC]
# datetime64[ns, UTC]
# datetime64[ns, UTC]
# datetime64[ns, UTC]
# int64
# float64

# %%
# checking for irregularities in categorical variables
categorical_columns = trip_riders_drivers_df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['trip_id', 'user_id', 'driver_id', 'payment_type', 'weather',
#        'loyalty_status', 'vehicle_type', 'city'],
#       dtype='object')

# %%
cat_columns = ['payment_type', 'weather', 'loyalty_status', 'vehicle_type', 'city']
for col in cat_columns:
    print(col)
    print(trip_riders_drivers_df[col].unique())
    print()
# Out:
# payment_type
# ['Mobile Money' 'Card' 'Cash']
#
# weather
# ['Cloudy' 'Sunny' 'Rainy' 'Foggy']
#
# loyalty_status
# ['Silver' 'Bronze' 'Gold' 'Platinum']
#
# vehicle_type
# ['SUV' 'Sedan' 'Motorcycle' 'Luxury']
#
# city
# ['Cairo' 'Nairobi' 'Lagos']

# %%
trip_riders_drivers_df.head(2)
# Out:
#    trip_id user_id driver_id   fare  surge_multiplier   tip  payment_type  \
# 0  T090716  R00102    D00000   5.07               1.0  0.00  Mobile Money
# 1  T113266  R01412    D00000  19.69               1.0  0.44  Mobile Money
#
#                 pickup_time              dropoff_time  pickup_lat  ...  \
# 0 2025-03-14 08:29:08+00:00 2025-03-14 09:08:08+00:00   30.013226  ...
# 1 2025-03-04 08:23:47+00:00 2025-03-04 09:10:47+00:00   30.131991  ...
#
#            user_signup_date  age  rating_by_driver churn_prob rating_by_rider  \
# 0 2023-11-01 00:00:00+00:00   37               4.4   0.411712             3.1
# 1 2024-05-23 00:00:00+00:00   24               4.6   0.196812             3.1
#
#   vehicle_type        driver_signup_date                      last_active  \
# 0          SUV 2025-01-20 00:00:00+00:00 2025-01-06 18:23:09.312275+00:00
# 1          SUV 2025-01-20 00:00:00+00:00 2025-01-06 18:23:09.312275+00:00
#
#     city  acceptance_rate
# 0  Cairo         0.679555
# 1  Cairo         0.679555
#
# [2 rows x 25 columns]

# %% [markdown]
# #### **Cleaning the customer signup dates:** Cleaning and adjusting the inconsistency where a user's first recorded trip appears before their official signup date.

# %%
# Finding earliest trips for each user
earliest_user_trips = trip_riders_drivers_df.groupby('user_id')['pickup_time'].min().reset_index()
earliest_user_trips.columns = ['user_id', 'first_trip_recorded']   # replacing pickup_time with first_trip_recorded

# Merging this info back to see it alongside the signup date
# Looking at unique users for the explanation
user_dates = trip_riders_drivers_df[['user_id', 'user_signup_date']].drop_duplicates().merge(earliest_user_trips, on='user_id')

user_dates['user_adjusted_signup_date'] = user_dates[['user_signup_date', 'first_trip_recorded']].min(axis=1)   # Applying the "Simple Fix" logic by using the minimum of the two

# Flag rows where a change happened
user_dates['was_adjusted_for_users'] = user_dates['user_adjusted_signup_date'] < user_dates['user_signup_date']

# Showing the results for the breakdown
print("Total Unique Users:", len(user_dates))
print("Users requiring adjustment:", user_dates['was_adjusted_for_users'].sum())
user_dates.head(2)
# Out:
# Total Unique Users: 10000
# Users requiring adjustment: 4717
#   user_id          user_signup_date       first_trip_recorded  \
# 0  R00102 2023-11-01 00:00:00+00:00 2024-05-03 22:40:21+00:00
# 1  R01412 2024-05-23 00:00:00+00:00 2024-05-02 17:33:32+00:00
#
#   user_adjusted_signup_date  was_adjusted_for_users
# 0 2023-11-01 00:00:00+00:00                   False
# 1 2024-05-02 17:33:32+00:00                    True

# %%
trip_riders_drivers_df = trip_riders_drivers_df.merge(
    user_dates[['user_id', 'user_adjusted_signup_date']],
    on='user_id',
    how='left'
)

trip_riders_drivers_df['user_signup_date'] = trip_riders_drivers_df['user_adjusted_signup_date']
trip_riders_drivers_df.drop(columns=['user_adjusted_signup_date'], inplace=True)  # dropping the 'adjusted_signup_date' column

# %%
trip_riders_drivers_df[['user_signup_date', 'pickup_time']].head().reset_index(drop=True)
# Out:
#            user_signup_date               pickup_time
# 0 2023-11-01 00:00:00+00:00 2025-03-14 08:29:08+00:00
# 1 2024-05-02 17:33:32+00:00 2025-03-04 08:23:47+00:00
# 2 2024-05-15 15:06:22+00:00 2025-03-09 15:33:44+00:00
# 3 2023-08-29 00:00:00+00:00 2024-07-20 16:57:17+00:00
# 4 2023-06-01 00:00:00+00:00 2024-05-29 12:09:12+00:00

# %%
trip_riders_drivers_df['pickup_time'].dtype
# Out:
# datetime64[ns, UTC]

# %%
trip_riders_drivers_df['dropoff_date'] = trip_riders_drivers_df['pickup_time'].dt.date                              # Step 2: Extract the date part
trip_riders_drivers_df['dropoff_day'] = trip_riders_drivers_df['pickup_time'].dt.day_name()                         # Step 4: Extract the day of the week
trip_riders_drivers_df['dropoff_date'] = pd.to_datetime(trip_riders_drivers_df['dropoff_date'])

trip_riders_drivers_df.shape
# Out:
# (200000, 27)

# %% [markdown]
# #

# %% [markdown]
# #### **Applying the same approach to correct the drivers sign up date to adjust the inconsistency where a driver's first recorded trip appears before their official signup date.**

# %%
# Finding earliest trips for each driver
earliest_driver_trips = trip_riders_drivers_df.groupby('driver_id')['pickup_time'].min().reset_index()
earliest_driver_trips.columns = ['driver_id', 'first_trip_recorded']   # replacing pickup_time with first_trip_recorded

# Merging this info back to see it alongside the signup date
# Looking at unique drivers for the explanation
driver_dates = trip_riders_drivers_df[['driver_id', 'driver_signup_date']].drop_duplicates().merge(earliest_driver_trips, on='driver_id')
driver_dates['driver_adjusted_signup_date'] = driver_dates[['driver_signup_date', 'first_trip_recorded']].min(axis=1)    # Applying the "Simple Fix" logic by using the minimum of the two
driver_dates['was_adjusted_for_drivers'] = driver_dates['driver_adjusted_signup_date'] < driver_dates['driver_signup_date']              # Flag rows where a change happened

# Showing the results for the breakdown
print("Total Unique Users:", len(driver_dates))
print("Users requiring adjustment:", driver_dates['was_adjusted_for_drivers'].sum())
driver_dates.head(2)
# Out:
# Total Unique Users: 5000
# Users requiring adjustment: 1635
#   driver_id        driver_signup_date       first_trip_recorded  \
# 0    D00000 2025-01-20 00:00:00+00:00 2024-05-17 05:10:54+00:00
# 1    D00001 2023-03-27 00:00:00+00:00 2024-04-29 06:40:21+00:00
#
#   driver_adjusted_signup_date  was_adjusted_for_drivers
# 0   2024-05-17 05:10:54+00:00                      True
# 1   2023-03-27 00:00:00+00:00                     False

# %%
trip_riders_drivers_df = trip_riders_drivers_df.merge(
    driver_dates[['driver_id', 'driver_adjusted_signup_date']],
    on='driver_id',
    how='left'
)

trip_riders_drivers_df['driver_signup_date'] = trip_riders_drivers_df['driver_adjusted_signup_date']
trip_riders_drivers_df.drop(columns=['driver_adjusted_signup_date'], inplace=True)  # dropping the 'adjusted_signup_date' column

# %% [markdown]
# **feature engineered with 'trip_duration_mins'**

# %%
trip_riders_drivers_df['trip_duration_mins'] = (trip_riders_drivers_df['dropoff_time'] - trip_riders_drivers_df['pickup_time']).dt.total_seconds() / 60
trip_riders_drivers_df['trip_duration_mins'] = trip_riders_drivers_df['trip_duration_mins'].astype(int)
trip_riders_drivers_df['trip_duration_mins'].head(3).reset_index(drop=True)
# Out:
# 0    39
# 1    47
# 2    48
# Name: trip_duration_mins, dtype: int64

# %%
trip_riders_drivers_df[trip_riders_drivers_df['trip_duration_mins'] <= 0]      # this shows that all trips were completed
# Out:
# Empty DataFrame
# Columns: [trip_id, user_id, driver_id, fare, surge_multiplier, tip, payment_type, pickup_time, dropoff_time, pickup_lat, pickup_lng, dropoff_lat, dropoff_lng, weather, loyalty_status, user_signup_date, age, rating_by_driver, churn_prob, rating_by_rider, vehicle_type, driver_signup_date, last_active, city, acceptance_rate, dropoff_date, dropoff_day, trip_duration_mins]
# Index: []
#
# [0 rows x 28 columns]

# %%
trip_riders_drivers_df['user_signup_date'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **'rider_age_group' feature engineered**

# %%
def age_group(age):
    if age <= 24:
        return 'Young Starters'
    elif age <= 34:
        return 'Early Career Adults'
    elif age <= 50:
        return 'Mid-Career Adults'
    elif age <= 64:
        return 'Late Career Adults'
    else:
        return 'Senior Citizens'


trip_riders_drivers_df['rider_age_group'] = trip_riders_drivers_df['age'].apply(age_group)
trip_riders_drivers_df[['age','rider_age_group']].head(3).reset_index(drop=True)
# Out:
#    age     rider_age_group
# 0   37   Mid-Career Adults
# 1   24      Young Starters
# 2   61  Late Career Adults

# %% [markdown]
# #

# %% [markdown]
# **`pickup_hour`, `pickup_period`, `pickup_day`, `pickup_month`, `pickup_season` and `pickup_year`: features engineered**

# %%
trip_riders_drivers_df['pickup_hour'] = trip_riders_drivers_df['pickup_time'].dt.hour
trip_riders_drivers_df['pickup_date'] = trip_riders_drivers_df['pickup_time'].dt.date
trip_riders_drivers_df['pickup_day'] = trip_riders_drivers_df['pickup_time'].dt.day_name()
trip_riders_drivers_df['pickup_month'] = trip_riders_drivers_df['pickup_time'].dt.month_name()
trip_riders_drivers_df['pickup_year'] = trip_riders_drivers_df['pickup_time'].dt.year

def pickup_period(hour):
    if 0 <= hour < 4:
        return 'Late Night'
    elif 4 <= hour < 8:
        return 'Early Morning'
    elif 8 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 16:
        return 'Afternoon'
    elif 16 <= hour < 20:
        return 'Evening'
    else:
        return 'Night'

trip_riders_drivers_df['pickup_period'] = trip_riders_drivers_df['pickup_time'].apply(lambda x: pickup_period(x.hour))

# Define seasons
season_map = { 'December': 'Winter', 'January': 'Winter', 'February': 'Winter',
              'March': 'Spring', 'April': 'Spring', 'May': 'Spring',
               'June': 'Summer', 'July': 'Summer', 'August': 'Summer',
               'September': 'Autumn', 'October': 'Autumn', 'November': 'Autumn' }

trip_riders_drivers_df['pickup_season'] = trip_riders_drivers_df['pickup_month'].map(season_map)    # Create a new pickup_season column

trip_riders_drivers_df[['pickup_hour','pickup_period','pickup_day','pickup_month','pickup_season', 'pickup_year']].head(3).reset_index(drop=True)
# Out:
#    pickup_hour pickup_period pickup_day pickup_month pickup_season  \
# 0            8       Morning     Friday        March        Spring
# 1            8       Morning    Tuesday        March        Spring
# 2           15     Afternoon     Sunday        March        Spring
#
#    pickup_year
# 0         2025
# 1         2025
# 2         2025

# %% [markdown]
# #

# %%
trip_riders_drivers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 36 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_id             200000 non-null  object
#  1   user_id             200000 non-null  object
#  2   driver_id           200000 non-null  object
#  3   fare                200000 non-null  float64
#  4   surge_multiplier    200000 non-null  float64
#  5   tip                 200000 non-null  float64
#  6   payment_type        200000 non-null  object
#  7   pickup_time         200000 non-null  datetime64[ns, UTC]
#  8   dropoff_time        200000 non-null  datetime64[ns, UTC]
#  9   pickup_lat          200000 non-null  float64
#  10  pickup_lng          200000 non-null  float64
#  11  dropoff_lat         200000 non-null  float64
#  12  dropoff_lng         200000 non-null  float64
#  13  weather             200000 non-null  object
#  14  loyalty_status      200000 non-null  object
#  15  user_signup_date    200000 non-null  datetime64[ns, UTC]
#  16  age                 200000 non-null  int64
#  17  rating_by_driver    200000 non-null  float64
#  18  churn_prob          200000 non-null  float64
#  19  rating_by_rider     200000 non-null  float64
#  20  vehicle_type        200000 non-null  object
#  21  driver_signup_date  200000 non-null  datetime64[ns, UTC]
#  22  last_active         200000 non-null  datetime64[ns, UTC]
#  23  city                200000 non-null  object
#  24  acceptance_rate     200000 non-null  float64
#  25  dropoff_date        200000 non-null  datetime64[ns]
#  26  dropoff_day         200000 non-null  object
#  27  trip_duration_mins  200000 non-null  int64
#  28  rider_age_group     200000 non-null  object
#  29  pickup_hour         200000 non-null  int32
#  30  pickup_date         200000 non-null  object
#  31  pickup_day          200000 non-null  object
#  32  pickup_month        200000 non-null  object
#  33  pickup_year         200000 non-null  int32
#  34  pickup_period       200000 non-null  object
#  35  pickup_season       200000 non-null  object
# dtypes: datetime64[ns, UTC](5), datetime64[ns](1), float64(11), int32(2), int64(2), object(15)
# memory usage: 53.4+ MB

# %%
trip_riders_drivers_df.to_csv('/content/drive/MyDrive/RideWise_Project/trip_riders_drivers_df.csv', index=False)

# %%
trip_riders_drivers_df.columns
# Out:
# Index(['trip_id', 'user_id', 'driver_id', 'fare', 'surge_multiplier', 'tip',
#        'payment_type', 'pickup_time', 'dropoff_time', 'pickup_lat',
#        'pickup_lng', 'dropoff_lat', 'dropoff_lng', 'weather', 'loyalty_status',
#        'user_signup_date', 'age', 'rating_by_driver', 'churn_prob',
#        'rating_by_rider', 'vehicle_type', 'driver_signup_date', 'last_active',
#        'city', 'acceptance_rate', 'dropoff_date', 'dropoff_day',
#        'trip_duration_mins', 'rider_age_group', 'pickup_hour', 'pickup_date',
#        'pickup_day', 'pickup_month', 'pickup_year', 'pickup_period',
#        'pickup_season'],
#       dtype='object')

# %%
sessions_df.head()
# Out:
#   session_id user_id               session_time  time_on_app  pages_visited  \
# 0    S000000  R08605  2025-04-27 18:57:06+02:05           79              4
# 1    S000001  R08823  2025-04-27 07:32:22+02:27          101              3
# 2    S000002  R05342  2025-04-27 23:17:25+02:05           12              1
# 3    S000003  R05057  2025-04-27 14:40:25+00:14           19              1
# 4    S000004  R09614  2025-04-27 08:31:22+00:14            4              1
#
#    converted     city loyalty_status
# 0          1    Cairo         Bronze
# 1          0  Nairobi         Silver
# 2          0    Cairo         Bronze
# 3          0    Lagos         Silver
# 4          0    Lagos         Bronze

# %%
trip_riders_drivers_df.describe(include='all').transpose()
# Out:
#                        count  unique                top    freq  \
# trip_id               200000  200000            T172808       1
# user_id               200000   10000             R08152      42
# driver_id             200000    5000             D03093      67
# fare                200000.0     NaN                NaN     NaN
# surge_multiplier    200000.0     NaN                NaN     NaN
# tip                 200000.0     NaN                NaN     NaN
# payment_type          200000       3               Card  100326
# pickup_time           200000     NaN                NaN     NaN
# dropoff_time          200000     NaN                NaN     NaN
# pickup_lat          200000.0     NaN                NaN     NaN
# pickup_lng          200000.0     NaN                NaN     NaN
# dropoff_lat         200000.0     NaN                NaN     NaN
# dropoff_lng         200000.0     NaN                NaN     NaN
# weather               200000       4              Sunny  120151
# loyalty_status        200000       4             Bronze  121252
# user_signup_date      200000     NaN                NaN     NaN
# age                 200000.0     NaN                NaN     NaN
# rating_by_driver    200000.0     NaN                NaN     NaN
# churn_prob          200000.0     NaN                NaN     NaN
# rating_by_rider     200000.0     NaN                NaN     NaN
# vehicle_type          200000       4              Sedan   97933
# driver_signup_date    200000     NaN                NaN     NaN
# last_active           200000     NaN                NaN     NaN
# city                  200000       3              Cairo   67436
# acceptance_rate     200000.0     NaN                NaN     NaN
# dropoff_date          200000     NaN                NaN     NaN
# dropoff_day           200000       7             Sunday   29012
# trip_duration_mins  200000.0     NaN                NaN     NaN
# rider_age_group       200000       5  Mid-Career Adults   89340
# pickup_hour         200000.0     NaN                NaN     NaN
# pickup_date           200000     367         2025-03-27     625
# pickup_day            200000       7             Sunday   29012
# pickup_month          200000      12             August   17219
# pickup_year         200000.0     NaN                NaN     NaN
# pickup_period         200000       6            Evening   52726
# pickup_season         200000       4             Spring   50509
#
#                                                    mean  \
# trip_id                                             NaN
# user_id                                             NaN
# driver_id                                           NaN
# fare                                          15.401285
# surge_multiplier                               1.141499
# tip                                            0.469566
# payment_type                                        NaN
# pickup_time         2024-10-27 02:05:30.728254976+00:00
# dropoff_time        2024-10-27 02:37:28.166854656+00:00
# pickup_lat                                      11.8496
# pickup_lng                                    23.924133
# dropoff_lat                                   11.849589
# dropoff_lng                                   23.924173
# weather                                             NaN
# loyalty_status                                      NaN
# user_signup_date    2024-02-03 22:42:37.204574976+00:00
# age                                            34.66165
# rating_by_driver                               4.461348
# churn_prob                                     0.285692
# rating_by_rider                                4.173625
# vehicle_type                                        NaN
# driver_signup_date  2023-08-27 07:50:24.093629952+00:00
# last_active         2025-03-07 14:07:45.161060096+00:00
# city                                                NaN
# acceptance_rate                                0.694781
# dropoff_date              2024-10-26 13:50:16.512000256
# dropoff_day                                         NaN
# trip_duration_mins                             31.95731
# rider_age_group                                     NaN
# pickup_hour                                    11.75333
# pickup_date                                         NaN
# pickup_day                                          NaN
# pickup_month                                        NaN
# pickup_year                                 2024.319845
# pickup_period                                       NaN
# pickup_season                                       NaN
#
#                                                  min  \
# trip_id                                          NaN
# user_id                                          NaN
# driver_id                                        NaN
# fare                                            2.97
# surge_multiplier                                 1.0
# tip                                              0.0
# payment_type                                     NaN
# pickup_time                2024-04-26 21:40:34+00:00
# dropoff_time               2024-04-26 22:05:31+00:00
# pickup_lat                                  -1.78636
# pickup_lng                                  2.879224
# dropoff_lat                                 -1.83322
# dropoff_lng                                 2.830979
# weather                                          NaN
# loyalty_status                                   NaN
# user_signup_date           2023-04-27 00:00:00+00:00
# age                                             18.0
# rating_by_driver                                 2.6
# churn_prob                                  0.002934
# rating_by_rider                                  3.1
# vehicle_type                                     NaN
# driver_signup_date         2022-04-27 00:00:00+00:00
# last_active         2022-04-28 16:45:23.765979+00:00
# city                                             NaN
# acceptance_rate                                  0.1
# dropoff_date                     2024-04-26 00:00:00
# dropoff_day                                      NaN
# trip_duration_mins                               5.0
# rider_age_group                                  NaN
# pickup_hour                                      0.0
# pickup_date                                      NaN
# pickup_day                                       NaN
# pickup_month                                     NaN
# pickup_year                                   2024.0
# pickup_period                                    NaN
# pickup_season                                    NaN
#
#                                                     25%  \
# trip_id                                             NaN
# user_id                                             NaN
# driver_id                                           NaN
# fare                                               11.0
# surge_multiplier                                    1.0
# tip                                                 0.0
# payment_type                                        NaN
# pickup_time         2024-07-28 05:28:59.750000128+00:00
# dropoff_time        2024-07-28 05:56:58.750000128+00:00
# pickup_lat                                    -1.172683
# pickup_lng                                     3.496574
# dropoff_lat                                   -1.172868
# dropoff_lng                                    3.497195
# weather                                             NaN
# loyalty_status                                      NaN
# user_signup_date              2023-10-27 00:00:00+00:00
# age                                                28.0
# rating_by_driver                                    4.2
# churn_prob                                     0.161546
# rating_by_rider                                     3.7
# vehicle_type                                        NaN
# driver_signup_date            2023-01-18 00:00:00+00:00
# last_active         2025-03-13 12:30:52.353133056+00:00
# city                                                NaN
# acceptance_rate                                0.564874
# dropoff_date                        2024-07-28 00:00:00
# dropoff_day                                         NaN
# trip_duration_mins                                 18.0
# rider_age_group                                     NaN
# pickup_hour                                         6.0
# pickup_date                                         NaN
# pickup_day                                          NaN
# pickup_month                                        NaN
# pickup_year                                      2024.0
# pickup_period                                       NaN
# pickup_season                                       NaN
#
#                                                     50%  \
# trip_id                                             NaN
# user_id                                             NaN
# driver_id                                           NaN
# fare                                              14.13
# surge_multiplier                                    1.0
# tip                                                 0.0
# payment_type                                        NaN
# pickup_time                   2024-10-27 03:27:51+00:00
# dropoff_time           2024-10-27 03:48:26.500000+00:00
# pickup_lat                                     6.525574
# pickup_lng                                    31.238814
# dropoff_lat                                    6.525235
# dropoff_lng                                   31.239118
# weather                                             NaN
# loyalty_status                                      NaN
# user_signup_date              2024-04-25 00:00:00+00:00
# age                                                35.0
# rating_by_driver                                    4.5
# churn_prob                                     0.265622
# rating_by_rider                                     4.2
# vehicle_type                                        NaN
# driver_signup_date            2023-10-19 00:00:00+00:00
# last_active         2025-04-08 11:09:10.464143104+00:00
# city                                                NaN
# acceptance_rate                                0.696067
# dropoff_date                        2024-10-27 00:00:00
# dropoff_day                                         NaN
# trip_duration_mins                                 32.0
# rider_age_group                                     NaN
# pickup_hour                                        12.0
# pickup_date                                         NaN
# pickup_day                                          NaN
# pickup_month                                        NaN
# pickup_year                                      2024.0
# pickup_period                                       NaN
# pickup_season                                       NaN
#
#                                                     75%  \
# trip_id                                             NaN
# user_id                                             NaN
# driver_id                                           NaN
# fare                                              18.35
# surge_multiplier                                    1.2
# tip                                                 0.4
# payment_type                                        NaN
# pickup_time                   2025-01-26 12:48:44+00:00
# dropoff_time        2025-01-26 13:20:24.249999872+00:00
# pickup_lat                                    29.934766
# pickup_lng                                    36.703772
# dropoff_lat                                   29.935056
# dropoff_lng                                   36.704067
# weather                                             NaN
# loyalty_status                                      NaN
# user_signup_date              2024-05-08 17:06:18+00:00
# age                                                41.0
# rating_by_driver                                    4.8
# churn_prob                                     0.388132
# rating_by_rider                                     4.7
# vehicle_type                                        NaN
# driver_signup_date            2024-04-30 00:00:00+00:00
# last_active         2025-04-19 19:34:36.690178048+00:00
# city                                                NaN
# acceptance_rate                                0.835793
# dropoff_date                        2025-01-26 00:00:00
# dropoff_day                                         NaN
# trip_duration_mins                                 46.0
# rider_age_group                                     NaN
# pickup_hour                                        17.0
# pickup_date                                         NaN
# pickup_day                                          NaN
# pickup_month                                        NaN
# pickup_year                                      2025.0
# pickup_period                                       NaN
# pickup_season                                       NaN
#
#                                                  max        std
# trip_id                                          NaN        NaN
# user_id                                          NaN        NaN
# driver_id                                        NaN        NaN
# fare                                           82.74   6.163199
# surge_multiplier                                 3.8   0.255362
# tip                                            21.86   1.100545
# payment_type                                     NaN        NaN
# pickup_time                2025-04-27 23:43:26+00:00        NaN
# dropoff_time               2025-04-28 00:12:26+00:00        NaN
# pickup_lat                                 30.544251  13.362151
# pickup_lng                                  37.31709  14.577572
# dropoff_lat                                30.592457  13.362229
# dropoff_lng                                37.364817  14.577642
# weather                                          NaN        NaN
# loyalty_status                                   NaN        NaN
# user_signup_date           2024-11-30 11:35:14+00:00        NaN
# age                                             70.0   9.508071
# rating_by_driver                                 5.0   0.428432
# churn_prob                                  0.913302   0.159011
# rating_by_rider                                  5.0   0.594107
# vehicle_type                                     NaN        NaN
# driver_signup_date         2024-07-03 00:22:02+00:00        NaN
# last_active         2025-04-27 16:20:56.061019+00:00        NaN
# city                                             NaN        NaN
# acceptance_rate                                 0.99   0.185828
# dropoff_date                     2025-04-27 00:00:00        NaN
# dropoff_day                                      NaN        NaN
# trip_duration_mins                              59.0  15.871754
# rider_age_group                                  NaN        NaN
# pickup_hour                                     23.0   5.755028
# pickup_date                                      NaN        NaN
# pickup_day                                       NaN        NaN
# pickup_month                                     NaN        NaN
# pickup_year                                   2025.0   0.466417
# pickup_period                                    NaN        NaN
# pickup_season                                    NaN        NaN
